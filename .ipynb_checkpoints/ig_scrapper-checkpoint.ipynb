# %% [markdown]
# # **Proyecto Instagram**
#
# # Cuenta uno:
# ### **Email:**
#
# redinstagramapp@gmail.com
#
# redinstagramapp2022
#
#
# ### **Instagram:**
#
# @proyectoredargentina
#
# redinstagram2019
#
#
# # Cuenta dos:
# ### **Email:**
#
# redinstagramapp2@gmail.com
#
# redinstagramapp2022
#
#
# ### **Instagram:**
#
# @proyectoredarg
#
# redinstagram2021
#
# ## **Facebook:**
# redinstagramapp@gmail.com
#
# redinstagramapp2022

# %%
# Usuarios a Scrapear
usuarios_interes = [
    
'mauriciomacri', 'cristinafkirchner', 'horaciorodriguezlarreta', 
 'joseluisespert', 'silbatakis', 'kicillofok', 'elisalilitacarrio','sergiomassaok', 
'coqui.capitanich', 'aliciakirchner', 'sergiounac', 'gustavovaldesok'
'juanluismanzur', 'gerardomoralesjujuy', 'gzamorasde', 'jschiaretti'         
'mariuvidal','patobullrich','gugalusto','alferdezok','javiermilei',  
    
]

# %%
import os
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from time import sleep
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.headless = True
# !pip install webdriver-manager
from webdriver_manager.chrome import ChromeDriverManager
import random
import pandas as pd
import numpy as np
# !pip install Workbook
# !pip install openpyxl
import openpyxl
from openpyxl import Workbook
import re
# Out:
# Requirement already satisfied: selenium in c:\users\felipe\miniconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\felipe\miniconda3\lib\site-packages (from selenium) (1.24.3)
# Requirement already satisfied: webdriver-manager in c:\users\felipe\miniconda3\lib\site-packages (3.2.2)
# Requirement already satisfied: crayons in c:\users\felipe\miniconda3\lib\site-packages (from webdriver-manager) (0.4.0)
# Requirement already satisfied: configparser in c:\users\felipe\miniconda3\lib\site-packages (from webdriver-manager) (5.0.1)
# Requirement already satisfied: requests in c:\users\felipe\miniconda3\lib\site-packages (from webdriver-manager) (2.21.0)
# Requirement already satisfied: colorama in c:\users\felipe\miniconda3\lib\site-packages (from crayons->webdriver-manager) (0.4.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\felipe\miniconda3\lib\site-packages (from requests->webdriver-manager) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\felipe\miniconda3\lib\site-packages (from requests->webdriver-manager) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\felipe\miniconda3\lib\site-packages (from requests->webdriver-manager) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\felipe\miniconda3\lib\site-packages (from requests->webdriver-manager) (1.24.3)
# Requirement already satisfied: Workbook in c:\users\felipe\miniconda3\lib\site-packages (1.1)
# Requirement already satisfied: xlwt in c:\users\felipe\miniconda3\lib\site-packages (from Workbook) (1.3.0)
# Requirement already satisfied: xlutils in c:\users\felipe\miniconda3\lib\site-packages (from Workbook) (2.0.0)
# Requirement already satisfied: xlrd>=0.7.2 in c:\users\felipe\miniconda3\lib\site-packages (from xlutils->Workbook) (2.0.1)
# Requirement already satisfied: openpyxl in c:\users\felipe\miniconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in c:\users\felipe\miniconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
# Usuarios a Scrapear
df = pd.read_excel('senadores.xlsx')
df.fillna('', inplace=True)
df = df[df['igs']!='']
usuarios_interes = [u.split('/')[3] for u in df['igs'].values]
usuarios_interes = usuarios_interes[usuarios_interes.index('alfredodeangeli'):]

# %%
# Credenciales
user = "proyectoredargentina"
password = "redinstagram2019"

# %%
class igScraper():
    def __init__(self):
        pass

    def login(self, user, password, navegacion_con_headers = False):

        # Funcion para evadir carteles
        def clickear(texto):
            self.path = f'//*[text() = "{texto}"]'
            self.boton = self.driver.find_element('xpath', self.path) 
            sleep(1)
            self.boton.click()
            sleep(2)

        # instanciamos webdriver (True or False)
        if navegacion_con_headers == True:
            self.driver = webdriver.Chrome(ChromeDriverManager().install())
        else:
            self.driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)

        # ir a instagram.com
        self.driver.get('https://instagram.com/')
        sleep(10)

        # poner usuario
        username = self.driver.find_element('name','username')
        sleep(1)
        username.click()
        sleep(1)
        username.send_keys(user)
        sleep(1)

        # poner contraseña
        pw = self.driver.find_element('name','password')
        sleep(2)
        pw.click()
        sleep(2)
        pw.send_keys(password)
        sleep(2)

        # login
        try:
            login_btn = self.driver.find_element('xpath','//div[text() = "Iniciar sesión"]')
        except:
            login_btn = self.driver.find_element('xpath','//div[text() = "Log In"]')
        sleep(2)
        login_btn.click()
        sleep(4)


        # Apretar "ahora no" a los pop ups, hasta que pueda buscarse un usuario
        contador_intentos = 0
        carteles_sorteados = False
        while carteles_sorteados == False and contador_intentos < 200:
            contador_intentos+=1
            try:
                buscador = self.driver.find_element('xpath',"//input[@placeholder='Buscar']")
                carteles_sorteados = True
            except:
                try:
                    buscador = self.driver.find_element('xpath',"//input[@placeholder='Search']")
                    carteles_sorteados = True
                except:
                    try:
                        clickear('Not Now')      
                    except:
                        try:
                            clickear('Ahora no')
                        except:
                            pass

        if contador_intentos == 200:
            print('\n\nEs posible que la cuenta haya sido blockeada.\n\n')

    def descargar(self, usuario, listado_seguidores, nombre):
        print(f'Guardando {nombre} de {usuario}...\n\n')
        nombre += '.xlsx'
        sumar = 0
        try:
            wb_obj = openpyxl.load_workbook(nombre)
            sumar += 1
        except:
            Workbook().save(nombre)
            wb_obj = openpyxl.load_workbook(nombre)

        # sheet
        worksheet = wb_obj.worksheets[0]

        # Columna de este usuario
        columna = worksheet.max_column + sumar

        # Nombre columna (usuario)
        worksheet.cell(row = 1, column = columna).value = usuario

        # Debajo, sus seguidos/seguidoress
        for i,s in enumerate(listado_seguidores):
            worksheet.cell(row = i+2, column = columna).value = s

        wb_obj.save(nombre)
        wb_obj.close()


    # SEGUIDORES
    def get_seguidores(self, usuario, cantidad_usuarios_a_scrapear= float('inf'), download= True):

        print(f'Scrapeando seguidores de {usuario}\n\n')

        url_usuario = 'https://www.instagram.com/'+usuario

        # Entrar al usuario
        self.driver.get(url_usuario)
        sleep(8)

        # Acceder a seguidores
        seguidores_boton = self.driver.find_element('xpath',"//ul[@class='_aa_7']/li[2]//span")
        seguidores_boton.click()
        sleep(3)

        # cantidad de seguidores
        can_seguidores = self.driver.find_element('xpath',"//ul[@class='_aa_7']/li[2]//span").text
        if '.' in can_seguidores:
            cantidad_decimal = len(can_seguidores.split('.')[-1][:-1])
        else:
            cantidad_decimal = 0
        can_seguidores = int(can_seguidores.replace('K','0'*(3-cantidad_decimal)).replace('M','0'*(6-cantidad_decimal)).replace('.','').replace(',',''))
        self.can_seguidores = can_seguidores
        
        # cuanto hay que scrollear
        scrollear_inicial = round(can_seguidores/12)+1

        # instanciamos seguidores_total
        seguidores_total = []
        cantidad_encontrados = []

        # scrollear y apendear
        for i in range(scrollear_inicial):
            i += 1

            #Cada x scrolls, pausa de x minutos
            if i % 10 == 0:
                minutos = random.uniform(3, 7)
                print(f'\n\n\nHaciendo pausa de {round(minutos)} minutos\n\n\n')
                time.sleep(minutos*60)

            # Cada x scrolls, scroll up to confuse bot detectors
            if i % 15 == 0:    
                self.driver.execute_script("""
                    var scrollt = document.querySelector('div[role="dialog"] ._aano')
                    scrollt.scrollTop = scrollt.scrollHeight - (scrollt.scrollHeight / 5)
                    """)

            # Print
            print(f'Scrolleando {i} de {scrollear_inicial}')

            # Scroll down
            self.driver.execute_script("""
                var scrollt = document.querySelector('div[role="dialog"] ._aano')
                scrollt.scrollTop = scrollt.scrollHeight
                """)

            time.sleep(random.uniform(20, 25))

            # Nuevos seguidores
            # Español
            seguidores = self.driver.find_elements('xpath',f"(//div[@class='_aae-']/li)[position()>={len(seguidores_total)}]//*/a")
            seguidores = [u.text for u in seguidores if len(u.text)>0]
            if len(seguidores) == 0:
                #Ingles
                seguidores = self.driver.find_elements('xpath',f"//div[position()>={len(seguidores_total)}]//*/span/a[@role = 'link']")
                seguidores = [elem.get_attribute('href').split('/')[-2] for elem in seguidores]

            # agregamos los nuevos seguidores
            seguidores_total.extend(seguidores)
            print(f'Hasta el momento, se han encontrado {len(seguidores_total)} seguidores de {usuario}\n')

            # Si no encontro nada en las ultimas 3 iters, break
            cantidad_encontrados.append(len(seguidores_total))
            try:
                ultimos = 20
                if len(set(cantidad_encontrados[-ultimos:])) == 1 and len(cantidad_encontrados) > ultimos:
                    print('\n\n\nINTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS\n')
                    break
            except:
                pass

            # break si se alcanzo maximo de usuarios
            if len(seguidores_total) > cantidad_usuarios_a_scrapear:
                break

            time.sleep(random.uniform(20, 25))

        return seguidores_total

    # SEGUIDOS
    def get_seguidos(self, usuario, cantidad_usuarios_a_scrapear= float('inf'), download= True):

        print(f'Scrapeando seguidos de {usuario}\n\n')

        url_usuario = 'https://www.instagram.com/'+usuario

        # Entrar al usuario
        self.driver.get(url_usuario)
        sleep(8)

        # Acceder a seguidos
        seguidos_boton = self.driver.find_element('xpath',"//ul[@class='_aa_7']/li[3]//span")
        seguidos_boton.click()
        sleep(3)

        # cantidad de seguidos
        can_seguidos = self.driver.find_element('xpath',"//ul[@class='_aa_7']/li[3]//span").text
        if '.' in can_seguidos:
            cantidad_decimal = len(can_seguidos.split('.')[-1][:-1])
        else:
            cantidad_decimal = 0
        can_seguidos = int(can_seguidos.replace('K','0'*(3-cantidad_decimal)).replace('M','0'*(6-cantidad_decimal)).replace('.','').replace(',',''))
        self.can_seguidos = can_seguidos
        
        # cuanto hay que scrollear
        scrollear_inicial = round(can_seguidos/12)+1

        # instanciamos seguidos_total
        seguidos_total = []
        cantidad_encontrados = []

        # scrollear y apendear
        for i in range(scrollear_inicial):
            i += 1

            # Cada x scrolls, pausa random
            if i % 10 == 0:
                minutos = random.uniform(3, 7)
                print(f'\n\n\nHaciendo pausa de {round(minutos)} minutos\n\n\n')
                time.sleep(minutos*60)


            # Cada x scrolls, scroll up to confuse bot detectors
            if i % 15 == 0:    
                self.driver.execute_script("""
                    var scrollt = document.querySelector('div[role="dialog"] ._aano')
                    scrollt.scrollTop = scrollt.scrollHeight - (scrollt.scrollHeight / 5)
                    """)

            # Print
            print(f'scrolleando {i} de {scrollear_inicial}')

            # Scroll down
            self.driver.execute_script("""
                var scrollt = document.querySelector('div[role="dialog"] ._aano')
                scrollt.scrollTop = scrollt.scrollHeight
                """)
            time.sleep(random.uniform(20, 25))


            # Nuevos seguidos
            # Español
            seguidos = self.driver.find_elements('xpath',f"(//div[@class='_aae-']/li)[position()>={len(seguidos_total)}]//*/a")
            seguidos = [u.text for u in seguidos if len(u.text)>0]
            if len(seguidos) == 0:
                #Ingles
                seguidos = self.driver.find_elements('xpath',f"//div[position()>={len(seguidos_total)}]//*/span/a[@role = 'link']")
                seguidos = [elem.get_attribute('href').split('/')[-2] for elem in seguidos]

            # agregamos los nuevos seguidos
            seguidos_total.extend(seguidos)
            print(f'Hasta el momento, se han encontrado {len(seguidos_total)} seguidos de {usuario}\n')

            # Si no encontro nada en las ultimas 4 iters, break
            cantidad_encontrados.append(len(seguidos_total))
            try:
                ultimos = 20
                if len(set(cantidad_encontrados[-ultimos:])) == 1 and len(cantidad_encontrados) > ultimos:
                    print('\n\n\nINTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS\n')
                    break
            except:
                pass

            # break si se alcanzo maximo de usuarios
            if len(seguidos_total) > cantidad_usuarios_a_scrapear:
                break

            time.sleep(random.uniform(20, 25))

        return seguidos_total

    def cantidad_usuarios(self, categoria):
        if categoria == 'seguidores':
            return self.can_seguidores
        else:
            return self.can_seguidos
        
    def logout(self):
        # Cerrar webdriver
        self.driver.close()
        print('\nDriver cerrado...\n')

# %%
seguidores_todos = {}
seguidos_todos = {}

start_total = time.time()

for usuario in usuarios_interes:
    start = time.time()
    
    porcentaje_encontrado = 0
    tiempo = 60*60

    while porcentaje_encontrado < 0.8:

        # Login
        sc = igScraper()
        sc.login(user, password, navegacion_con_headers = False)

        # Obtener seguidores/seguidos
        seguidos = sc.get_seguidos(usuario)

        porcentaje_encontrado = len(seguidos) / sc.cantidad_usuarios('seguidos')

        sc.logout()

        if porcentaje_encontrado < 0.8:
            tiempo *= 1.1
            print(f'\nHaciendo pausa de {round((tiempo/60/60),2)} horas.'), sleep(tiempo)

    # Guardarlo en dict
    seguidos_todos[usuario] = seguidos

    # Descarga
    sc.descargar(usuario, seguidos, 'seguidos')
    end = time.time()
    print(f'\n\n\n {usuario} tomo {round((end-start)/60)} minutos.\n\n\n')
    
    # pausa random
    horas = random.uniform(1, 2)
    print(f'\n\n\nHaciendo pausa inter usuario de {round(horas,2)} horas\n\n\n')
    time.sleep(horas*60*60)
    


end_total = time.time()

print(f'\n\n\nTodos los usuarios tomaron {round((end_total-start_total)/60)} minutos\n\n\n')
# Out:
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidos de alfredodeangeli
#
#
# scrolleando 1 de 156
# Hasta el momento, se han encontrado 24 seguidos de alfredodeangeli
#
# scrolleando 2 de 156
# Hasta el momento, se han encontrado 37 seguidos de alfredodeangeli
#
# scrolleando 3 de 156
# Hasta el momento, se han encontrado 49 seguidos de alfredodeangeli
#
# scrolleando 4 de 156
# Hasta el momento, se han encontrado 61 seguidos de alfredodeangeli
#
# scrolleando 5 de 156
# Hasta el momento, se han encontrado 73 seguidos de alfredodeangeli
#
# scrolleando 6 de 156
# Hasta el momento, se han encontrado 85 seguidos de alfredodeangeli
#
# scrolleando 7 de 156
# Hasta el momento, se han encontrado 97 seguidos de alfredodeangeli
#
# scrolleando 8 de 156
# Hasta el momento, se han encontrado 109 seguidos de alfredodeangeli
#
# scrolleando 9 de 156
# Hasta el momento, se han encontrado 121 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 6 minutos
#
#
#
# scrolleando 10 de 156
# Hasta el momento, se han encontrado 133 seguidos de alfredodeangeli
#
# scrolleando 11 de 156
# Hasta el momento, se han encontrado 145 seguidos de alfredodeangeli
#
# scrolleando 12 de 156
# Hasta el momento, se han encontrado 157 seguidos de alfredodeangeli
#
# scrolleando 13 de 156
# Hasta el momento, se han encontrado 169 seguidos de alfredodeangeli
#
# scrolleando 14 de 156
# Hasta el momento, se han encontrado 181 seguidos de alfredodeangeli
#
# scrolleando 15 de 156
# Hasta el momento, se han encontrado 193 seguidos de alfredodeangeli
#
# scrolleando 16 de 156
# Hasta el momento, se han encontrado 205 seguidos de alfredodeangeli
#
# scrolleando 17 de 156
# Hasta el momento, se han encontrado 217 seguidos de alfredodeangeli
#
# scrolleando 18 de 156
# Hasta el momento, se han encontrado 229 seguidos de alfredodeangeli
#
# scrolleando 19 de 156
# Hasta el momento, se han encontrado 241 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 6 minutos
#
#
#
# scrolleando 20 de 156
# Hasta el momento, se han encontrado 253 seguidos de alfredodeangeli
#
# scrolleando 21 de 156
# Hasta el momento, se han encontrado 265 seguidos de alfredodeangeli
#
# scrolleando 22 de 156
# Hasta el momento, se han encontrado 277 seguidos de alfredodeangeli
#
# scrolleando 23 de 156
# Hasta el momento, se han encontrado 289 seguidos de alfredodeangeli
#
# scrolleando 24 de 156
# Hasta el momento, se han encontrado 301 seguidos de alfredodeangeli
#
# scrolleando 25 de 156
# Hasta el momento, se han encontrado 313 seguidos de alfredodeangeli
#
# scrolleando 26 de 156
# Hasta el momento, se han encontrado 325 seguidos de alfredodeangeli
#
# scrolleando 27 de 156
# Hasta el momento, se han encontrado 337 seguidos de alfredodeangeli
#
# scrolleando 28 de 156
# Hasta el momento, se han encontrado 349 seguidos de alfredodeangeli
#
# scrolleando 29 de 156
# Hasta el momento, se han encontrado 361 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 7 minutos
#
#
#
# scrolleando 30 de 156
# Hasta el momento, se han encontrado 373 seguidos de alfredodeangeli
#
# scrolleando 31 de 156
# Hasta el momento, se han encontrado 385 seguidos de alfredodeangeli
#
# scrolleando 32 de 156
# Hasta el momento, se han encontrado 397 seguidos de alfredodeangeli
#
# scrolleando 33 de 156
# Hasta el momento, se han encontrado 409 seguidos de alfredodeangeli
#
# scrolleando 34 de 156
# Hasta el momento, se han encontrado 421 seguidos de alfredodeangeli
#
# scrolleando 35 de 156
# Hasta el momento, se han encontrado 433 seguidos de alfredodeangeli
#
# scrolleando 36 de 156
# Hasta el momento, se han encontrado 445 seguidos de alfredodeangeli
#
# scrolleando 37 de 156
# Hasta el momento, se han encontrado 457 seguidos de alfredodeangeli
#
# scrolleando 38 de 156
# Hasta el momento, se han encontrado 469 seguidos de alfredodeangeli
#
# scrolleando 39 de 156
# Hasta el momento, se han encontrado 481 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 5 minutos
#
#
#
# scrolleando 40 de 156
# Hasta el momento, se han encontrado 493 seguidos de alfredodeangeli
#
# scrolleando 41 de 156
# Hasta el momento, se han encontrado 505 seguidos de alfredodeangeli
#
# scrolleando 42 de 156
# Hasta el momento, se han encontrado 517 seguidos de alfredodeangeli
#
# scrolleando 43 de 156
# Hasta el momento, se han encontrado 529 seguidos de alfredodeangeli
#
# scrolleando 44 de 156
# Hasta el momento, se han encontrado 541 seguidos de alfredodeangeli
#
# scrolleando 45 de 156
# Hasta el momento, se han encontrado 553 seguidos de alfredodeangeli
#
# scrolleando 46 de 156
# Hasta el momento, se han encontrado 565 seguidos de alfredodeangeli
#
# scrolleando 47 de 156
# Hasta el momento, se han encontrado 577 seguidos de alfredodeangeli
#
# scrolleando 48 de 156
# Hasta el momento, se han encontrado 589 seguidos de alfredodeangeli
#
# scrolleando 49 de 156
# Hasta el momento, se han encontrado 601 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# scrolleando 50 de 156
# Hasta el momento, se han encontrado 613 seguidos de alfredodeangeli
#
# scrolleando 51 de 156
# Hasta el momento, se han encontrado 625 seguidos de alfredodeangeli
#
# scrolleando 52 de 156
# Hasta el momento, se han encontrado 637 seguidos de alfredodeangeli
#
# scrolleando 53 de 156
# Hasta el momento, se han encontrado 649 seguidos de alfredodeangeli
#
# scrolleando 54 de 156
# Hasta el momento, se han encontrado 661 seguidos de alfredodeangeli
#
# scrolleando 55 de 156
# Hasta el momento, se han encontrado 673 seguidos de alfredodeangeli
#
# scrolleando 56 de 156
# Hasta el momento, se han encontrado 685 seguidos de alfredodeangeli
#
# scrolleando 57 de 156
# Hasta el momento, se han encontrado 697 seguidos de alfredodeangeli
#
# scrolleando 58 de 156
# Hasta el momento, se han encontrado 709 seguidos de alfredodeangeli
#
# scrolleando 59 de 156
# Hasta el momento, se han encontrado 721 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 6 minutos
#
#
#
# scrolleando 60 de 156
# Hasta el momento, se han encontrado 733 seguidos de alfredodeangeli
#
# scrolleando 61 de 156
# Hasta el momento, se han encontrado 745 seguidos de alfredodeangeli
#
# scrolleando 62 de 156
# Hasta el momento, se han encontrado 757 seguidos de alfredodeangeli
#
# scrolleando 63 de 156
# Hasta el momento, se han encontrado 769 seguidos de alfredodeangeli
#
# scrolleando 64 de 156
# Hasta el momento, se han encontrado 781 seguidos de alfredodeangeli
#
# scrolleando 65 de 156
# Hasta el momento, se han encontrado 793 seguidos de alfredodeangeli
#
# scrolleando 66 de 156
# Hasta el momento, se han encontrado 805 seguidos de alfredodeangeli
#
# scrolleando 67 de 156
# Hasta el momento, se han encontrado 817 seguidos de alfredodeangeli
#
# scrolleando 68 de 156
# Hasta el momento, se han encontrado 829 seguidos de alfredodeangeli
#
# scrolleando 69 de 156
# Hasta el momento, se han encontrado 841 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 7 minutos
#
#
#
# scrolleando 70 de 156
# Hasta el momento, se han encontrado 853 seguidos de alfredodeangeli
#
# scrolleando 71 de 156
# Hasta el momento, se han encontrado 865 seguidos de alfredodeangeli
#
# scrolleando 72 de 156
# Hasta el momento, se han encontrado 877 seguidos de alfredodeangeli
#
# scrolleando 73 de 156
# Hasta el momento, se han encontrado 889 seguidos de alfredodeangeli
#
# scrolleando 74 de 156
# Hasta el momento, se han encontrado 901 seguidos de alfredodeangeli
#
# scrolleando 75 de 156
# Hasta el momento, se han encontrado 913 seguidos de alfredodeangeli
#
# scrolleando 76 de 156
# Hasta el momento, se han encontrado 925 seguidos de alfredodeangeli
#
# scrolleando 77 de 156
# Hasta el momento, se han encontrado 937 seguidos de alfredodeangeli
#
# scrolleando 78 de 156
# Hasta el momento, se han encontrado 949 seguidos de alfredodeangeli
#
# scrolleando 79 de 156
# Hasta el momento, se han encontrado 961 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# scrolleando 80 de 156
# Hasta el momento, se han encontrado 973 seguidos de alfredodeangeli
#
# scrolleando 81 de 156
# Hasta el momento, se han encontrado 985 seguidos de alfredodeangeli
#
# scrolleando 82 de 156
# Hasta el momento, se han encontrado 997 seguidos de alfredodeangeli
#
# scrolleando 83 de 156
# Hasta el momento, se han encontrado 1009 seguidos de alfredodeangeli
#
# scrolleando 84 de 156
# Hasta el momento, se han encontrado 1021 seguidos de alfredodeangeli
#
# scrolleando 85 de 156
# Hasta el momento, se han encontrado 1033 seguidos de alfredodeangeli
#
# scrolleando 86 de 156
# Hasta el momento, se han encontrado 1045 seguidos de alfredodeangeli
#
# scrolleando 87 de 156
# Hasta el momento, se han encontrado 1057 seguidos de alfredodeangeli
# scrolleando 88 de 156
# Hasta el momento, se han encontrado 1069 seguidos de alfredodeangeli
#
# scrolleando 89 de 156
# Hasta el momento, se han encontrado 1081 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# scrolleando 90 de 156
# Hasta el momento, se han encontrado 1093 seguidos de alfredodeangeli
#
# scrolleando 91 de 156
# Hasta el momento, se han encontrado 1105 seguidos de alfredodeangeli
#
# scrolleando 92 de 156
# Hasta el momento, se han encontrado 1117 seguidos de alfredodeangeli
#
# scrolleando 93 de 156
# Hasta el momento, se han encontrado 1129 seguidos de alfredodeangeli
#
# scrolleando 94 de 156
# Hasta el momento, se han encontrado 1141 seguidos de alfredodeangeli
#
# scrolleando 95 de 156
# Hasta el momento, se han encontrado 1153 seguidos de alfredodeangeli
#
# scrolleando 96 de 156
# Hasta el momento, se han encontrado 1165 seguidos de alfredodeangeli
#
# scrolleando 97 de 156
# Hasta el momento, se han encontrado 1177 seguidos de alfredodeangeli
#
# scrolleando 98 de 156
# Hasta el momento, se han encontrado 1189 seguidos de alfredodeangeli
#
# scrolleando 99 de 156
# Hasta el momento, se han encontrado 1201 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando 100 de 156
# Hasta el momento, se han encontrado 1213 seguidos de alfredodeangeli
#
# scrolleando 101 de 156
# Hasta el momento, se han encontrado 1225 seguidos de alfredodeangeli
#
# scrolleando 102 de 156
# Hasta el momento, se han encontrado 1237 seguidos de alfredodeangeli
#
# scrolleando 103 de 156
# Hasta el momento, se han encontrado 1249 seguidos de alfredodeangeli
#
# scrolleando 104 de 156
# Hasta el momento, se han encontrado 1261 seguidos de alfredodeangeli
#
# scrolleando 105 de 156
# Hasta el momento, se han encontrado 1273 seguidos de alfredodeangeli
#
# scrolleando 106 de 156
# Hasta el momento, se han encontrado 1285 seguidos de alfredodeangeli
#
# scrolleando 107 de 156
# Hasta el momento, se han encontrado 1297 seguidos de alfredodeangeli
#
# scrolleando 108 de 156
# Hasta el momento, se han encontrado 1309 seguidos de alfredodeangeli
#
# scrolleando 109 de 156
# Hasta el momento, se han encontrado 1321 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 6 minutos
#
#
#
# scrolleando 110 de 156
# Hasta el momento, se han encontrado 1333 seguidos de alfredodeangeli
#
# scrolleando 111 de 156
# Hasta el momento, se han encontrado 1345 seguidos de alfredodeangeli
#
# scrolleando 112 de 156
# Hasta el momento, se han encontrado 1357 seguidos de alfredodeangeli
#
# scrolleando 113 de 156
# Hasta el momento, se han encontrado 1369 seguidos de alfredodeangeli
#
# scrolleando 114 de 156
# Hasta el momento, se han encontrado 1381 seguidos de alfredodeangeli
#
# scrolleando 115 de 156
# Hasta el momento, se han encontrado 1393 seguidos de alfredodeangeli
#
# scrolleando 116 de 156
# Hasta el momento, se han encontrado 1405 seguidos de alfredodeangeli
#
# scrolleando 117 de 156
# Hasta el momento, se han encontrado 1417 seguidos de alfredodeangeli
#
# scrolleando 118 de 156
# Hasta el momento, se han encontrado 1429 seguidos de alfredodeangeli
#
# scrolleando 119 de 156
# Hasta el momento, se han encontrado 1441 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando 120 de 156
# Hasta el momento, se han encontrado 1453 seguidos de alfredodeangeli
#
# scrolleando 121 de 156
# Hasta el momento, se han encontrado 1465 seguidos de alfredodeangeli
#
# scrolleando 122 de 156
# Hasta el momento, se han encontrado 1477 seguidos de alfredodeangeli
#
# scrolleando 123 de 156
# Hasta el momento, se han encontrado 1489 seguidos de alfredodeangeli
#
# scrolleando 124 de 156
# Hasta el momento, se han encontrado 1501 seguidos de alfredodeangeli
#
# scrolleando 125 de 156
# Hasta el momento, se han encontrado 1513 seguidos de alfredodeangeli
#
# scrolleando 126 de 156
# Hasta el momento, se han encontrado 1525 seguidos de alfredodeangeli
#
# scrolleando 127 de 156
# Hasta el momento, se han encontrado 1537 seguidos de alfredodeangeli
#
# scrolleando 128 de 156
# Hasta el momento, se han encontrado 1549 seguidos de alfredodeangeli
#
# scrolleando 129 de 156
# Hasta el momento, se han encontrado 1561 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando 130 de 156
# Hasta el momento, se han encontrado 1573 seguidos de alfredodeangeli
#
# scrolleando 131 de 156
# Hasta el momento, se han encontrado 1585 seguidos de alfredodeangeli
#
# scrolleando 132 de 156
# Hasta el momento, se han encontrado 1597 seguidos de alfredodeangeli
#
# scrolleando 133 de 156
# Hasta el momento, se han encontrado 1609 seguidos de alfredodeangeli
#
# scrolleando 134 de 156
# Hasta el momento, se han encontrado 1621 seguidos de alfredodeangeli
#
# scrolleando 135 de 156
# Hasta el momento, se han encontrado 1633 seguidos de alfredodeangeli
#
# scrolleando 136 de 156
# Hasta el momento, se han encontrado 1645 seguidos de alfredodeangeli
#
# scrolleando 137 de 156
# Hasta el momento, se han encontrado 1657 seguidos de alfredodeangeli
#
# scrolleando 138 de 156
# Hasta el momento, se han encontrado 1669 seguidos de alfredodeangeli
#
# scrolleando 139 de 156
# Hasta el momento, se han encontrado 1681 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 7 minutos
#
#
#
# scrolleando 140 de 156
# Hasta el momento, se han encontrado 1693 seguidos de alfredodeangeli
#
# scrolleando 141 de 156
# Hasta el momento, se han encontrado 1705 seguidos de alfredodeangeli
#
# scrolleando 142 de 156
# Hasta el momento, se han encontrado 1717 seguidos de alfredodeangeli
#
# scrolleando 143 de 156
# Hasta el momento, se han encontrado 1729 seguidos de alfredodeangeli
#
# scrolleando 144 de 156
# Hasta el momento, se han encontrado 1741 seguidos de alfredodeangeli
#
# scrolleando 145 de 156
# Hasta el momento, se han encontrado 1753 seguidos de alfredodeangeli
#
# scrolleando 146 de 156
# Hasta el momento, se han encontrado 1765 seguidos de alfredodeangeli
#
# scrolleando 147 de 156
# Hasta el momento, se han encontrado 1777 seguidos de alfredodeangeli
#
# scrolleando 148 de 156
# Hasta el momento, se han encontrado 1789 seguidos de alfredodeangeli
#
# scrolleando 149 de 156
# Hasta el momento, se han encontrado 1801 seguidos de alfredodeangeli
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando 150 de 156
# Hasta el momento, se han encontrado 1813 seguidos de alfredodeangeli
#
# scrolleando 151 de 156
# Hasta el momento, se han encontrado 1825 seguidos de alfredodeangeli
#
# scrolleando 152 de 156
# Hasta el momento, se han encontrado 1837 seguidos de alfredodeangeli
#
# scrolleando 153 de 156
# Hasta el momento, se han encontrado 1849 seguidos de alfredodeangeli
#
# scrolleando 154 de 156
# Hasta el momento, se han encontrado 1861 seguidos de alfredodeangeli
#
# scrolleando 155 de 156
# Hasta el momento, se han encontrado 1864 seguidos de alfredodeangeli
#
# scrolleando 156 de 156
# Hasta el momento, se han encontrado 1864 seguidos de alfredodeangeli
#
#
# Driver cerrado...
#
# Guardando seguidos de alfredodeangeli...
#
#
#
#
#
#  alfredodeangeli tomo 194 minutos.
#
#
#
#
#
#
# Haciendo pausa inter usuario de 1.6617631656754037 horas
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
#
# Scrapeando seguidos de julianaditullio
#
#
# scrolleando 1 de 52
# Hasta el momento, se han encontrado 24 seguidos de julianaditullio
#
# scrolleando 2 de 52
# Hasta el momento, se han encontrado 37 seguidos de julianaditullio
#
# scrolleando 3 de 52
# Hasta el momento, se han encontrado 49 seguidos de julianaditullio
#
# scrolleando 4 de 52
# Hasta el momento, se han encontrado 61 seguidos de julianaditullio
#
# scrolleando 5 de 52
# Hasta el momento, se han encontrado 73 seguidos de julianaditullio
#
# scrolleando 6 de 52
# Hasta el momento, se han encontrado 85 seguidos de julianaditullio
#
# scrolleando 7 de 52
# Hasta el momento, se han encontrado 97 seguidos de julianaditullio
#
# scrolleando 8 de 52
# Hasta el momento, se han encontrado 109 seguidos de julianaditullio
#
# scrolleando 9 de 52
# Hasta el momento, se han encontrado 121 seguidos de julianaditullio
#
#
#
#
# Haciendo pausa de 7 minutos
#
#
#
# scrolleando 10 de 52
# Hasta el momento, se han encontrado 133 seguidos de julianaditullio
#
# scrolleando 11 de 52
# Hasta el momento, se han encontrado 145 seguidos de julianaditullio
#
# scrolleando 12 de 52
# Hasta el momento, se han encontrado 157 seguidos de julianaditullio
#
# scrolleando 13 de 52
# Hasta el momento, se han encontrado 169 seguidos de julianaditullio
#
# scrolleando 14 de 52
#
#
#
#
# Haciendo pausa de 5 minutos
#
#
#
# scrolleando 50 de 52
# Hasta el momento, se han encontrado 613 seguidos de julianaditullio
#
# scrolleando 51 de 52
# Hasta el momento, se han encontrado 615 seguidos de julianaditullio
#
# scrolleando 52 de 52
# Hasta el momento, se han encontrado 615 seguidos de julianaditullio
#
#
# Driver cerrado...
#
# Guardando seguidos de julianaditullio...
#
#
#
#
#
#  julianaditullio tomo 65 minutos.
#
#
#
#
#
#
# Haciendo pausa inter usuario de 1.5688648709381146 horas
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidos de martindonate
#
#
# scrolleando 1 de 17
# Hasta el momento, se han encontrado 24 seguidos de martindonate
#
# scrolleando 2 de 17
# Hasta el momento, se han encontrado 37 seguidos de martindonate
#
# scrolleando 3 de 17
# Hasta el momento, se han encontrado 49 seguidos de martindonate
#
# scrolleando 4 de 17
# Hasta el momento, se han encontrado 61 seguidos de martindonate
#
# scrolleando 5 de 17
# Hasta el momento, se han encontrado 73 seguidos de martindonate
#
# scrolleando 6 de 17
# Hasta el momento, se han encontrado 85 seguidos de martindonate
#
# scrolleando 7 de 17
# Hasta el momento, se han encontrado 97 seguidos de martindonate
#
# scrolleando 8 de 17
# Hasta el momento, se han encontrado 109 seguidos de martindonate
#
# scrolleando 9 de 17
# Hasta el momento, se han encontrado 121 seguidos de martindonate
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando 10 de 17
# Hasta el momento, se han encontrado 133 seguidos de martindonate
#
# scrolleando 11 de 17
# Hasta el momento, se han encontrado 145 seguidos de martindonate
#
# scrolleando 12 de 17
# Hasta el momento, se han encontrado 157 seguidos de martindonate
#
# scrolleando 13 de 17
# Hasta el momento, se han encontrado 169 seguidos de martindonate
#
# scrolleando 14 de 17
# Hasta el momento, se han encontrado 181 seguidos de martindonate
#
# scrolleando 15 de 17
# Hasta el momento, se han encontrado 193 seguidos de martindonate
#
# scrolleando 16 de 17
# Hasta el momento, se han encontrado 194 seguidos de martindonate
#
# scrolleando 17 de 17
# Hasta el momento, se han encontrado 194 seguidos de martindonate
#
#
# Driver cerrado...
#
# Guardando seguidos de martindonate...
#
#
#
#
#
#  martindonate tomo 18 minutos.
#
#
#
#
#
#
# Haciendo pausa inter usuario de 1.8322726693546745 horas
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/105.0.5195.52/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52]
# Scrapeando seguidos de eugeniadure
#
#
# scrolleando 1 de 195
# Hasta el momento, se han encontrado 24 seguidos de eugeniadure
#
# scrolleando 2 de 195
# Hasta el momento, se han encontrado 37 seguidos de eugeniadure
#
# scrolleando 3 de 195
# Hasta el momento, se han encontrado 49 seguidos de eugeniadure
#
# scrolleando 4 de 195
# Hasta el momento, se han encontrado 61 seguidos de eugeniadure
#
# scrolleando 5 de 195
# Hasta el momento, se han encontrado 73 seguidos de eugeniadure
#
# scrolleando 6 de 195
# Hasta el momento, se han encontrado 85 seguidos de eugeniadure
#
# scrolleando 7 de 195
# Hasta el momento, se han encontrado 97 seguidos de eugeniadure
#
# scrolleando 8 de 195
# Hasta el momento, se han encontrado 109 seguidos de eugeniadure
#
# scrolleando 9 de 195
# Hasta el momento, se han encontrado 121 seguidos de eugeniadure
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando
seguidos de anabelfsagasti
#
#
#
#
# Haciendo pausa de 6 minutos
#
#
#
# scrolleando 20 de 110
# Hasta el momento, se han encontrado 253 seguidos de anabelfsagasti
#
# scrolleando 21 de 110
# Hasta el momento, se han encontrado 265 seguidos de anabelfsagasti
#
# scrolleando 22 de 110
# Hasta el momento, se han encontrado 277 seguidos de anabelfsagasti
#
# scrolleando 23 de 110
# Hasta el momento, se han encontrado 289 seguidos de anabelfsagasti
#
# scrolleando 24 de 110
# Hasta el momento, se han encontrado 301 seguidos de anabelfsagasti
#
# scrolleando 25 de 110
# Hasta el momento, se han encontrado 313 seguidos de anabelfsagasti
#
# scrolleando 26 de 110
# Hasta el momento, se han encontrado 325 seguidos de anabelfsagasti
#
# scrolleando 27 de 110
# Hasta el momento, se han encontrado 337 seguidos de anabelfsagasti
#
# scrolleando 28 de 110
# Hasta el momento, se han encontrado 349 seguidos de anabelfsagasti
#
# scrolleando 29 de 110
# Hasta el momento, se han encontrado 361 seguidos de anabelfsagasti
#
#
#
#
# Haciendo pausa de 5 minutos
#
#
#
# scrolleando 30 de 110
# Hasta el momento, se han encontrado 373 seguidos de anabelfsagasti
#
# scrolleando 31 de 110
# Hasta el momento, se han encontrado 385 seguidos de anabelfsagasti
#
# scrolleando 32 de 110
# Hasta el momento, se han encontrado 397 seguidos de anabelfsagasti
#
# scrolleando 33 de 110
# Hasta el momento, se han encontrado 409 seguidos de anabelfsagasti
#
# scrolleando 34 de 110
# Hasta el momento, se han encontrado 421 seguidos de anabelfsagasti
#
# scrolleando 35 de 110
# Hasta el momento, se han encontrado 433 seguidos de anabelfsagasti
#
# scrolleando 36 de 110
# Hasta el momento, se han encontrado 445 seguidos de anabelfsagasti
#
# scrolleando 37 de 110
# Hasta el momento, se han encontrado 457 seguidos de anabelfsagasti
#
# scrolleando 38 de 110
# Hasta el momento, se han encontrado 469 seguidos de anabelfsagasti
#
# scrolleando 39 de 110
# Hasta el momento, se han encontrado 481 seguidos de anabelfsagasti
#
#
#
#
# Haciendo pausa de 7 minutos
#
#
#
# scrolleando 40 de 110
# Hasta el momento, se han encontrado 493 seguidos de anabelfsagasti
#
# scrolleando 41 de 110
# Hasta el momento, se han encontrado 505 seguidos de anabelfsagasti
#
# scrolleando 42 de 110
# Hasta el momento, se han encontrado 517 seguidos de anabelfsagasti
#
# scrolleando 43 de 110
# Hasta el momento, se han encontrado 529 seguidos de anabelfsagasti
#
# scrolleando 44 de 110
# Hasta el momento, se han encontrado 541 seguidos de anabelfsagasti
#
# scrolleando 45 de 110
# Hasta el momento, se han encontrado 553 seguidos de anabelfsagasti
#
# scrolleando 46 de 110
# Hasta el momento, se han encontrado 565 seguidos de anabelfsagasti
#
# scrolleando 47 de 110
# Hasta el momento, se han encontrado 577 seguidos de anabelfsagasti
#
# scrolleando 48 de 110
# Hasta el momento, se han encontrado 589 seguidos de anabelfsagasti
#
# scrolleando 49 de 110
# Hasta el momento, se han encontrado 601 seguidos de anabelfsagasti
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando 50 de 110
# Hasta el momento, se han encontrado 613 seguidos de anabelfsagasti
#
# scrolleando 51 de 110
# Hasta el momento, se han encontrado 625 seguidos de anabelfsagasti
#
# scrolleando 52 de 110
# Hasta el momento, se han encontrado 637 seguidos de anabelfsagasti
#
# scrolleando 53 de 110
# Hasta el momento, se han encontrado 649 seguidos de anabelfsagasti
#
# scrolleando 54 de 110
# Hasta el momento, se han encontrado 661 seguidos de anabelfsagasti
#
# scrolleando 55 de 110
# Hasta el momento, se han encontrado 673 seguidos de anabelfsagasti
#
# scrolleando 56 de 110
# Hasta el momento, se han encontrado 685 seguidos de anabelfsagasti
#
# scrolleando 57 de 110
# Hasta el momento, se han encontrado 697 seguidos de anabelfsagasti
#
# scrolleando 58 de 110
# Hasta el momento, se han encontrado 709 seguidos de anabelfsagasti
#
# scrolleando 59 de 110
# Hasta el momento, se han encontrado 721 seguidos de anabelfsagasti
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando
seguidos de anabelfsagasti
#
#
#
#
# Haciendo pausa de 5 minutos
#
#
#
# scrolleando 90 de 110
# Hasta el momento, se han encontrado 1093 seguidos de anabelfsagasti
#
# scrolleando 91 de 110
# Hasta el momento, se han encontrado 1105 seguidos de anabelfsagasti
#
# scrolleando 92 de 110
# Hasta el momento, se han encontrado 1117 seguidos de anabelfsagasti
#
# scrolleando 93 de 110
# Hasta el momento, se han encontrado 1129 seguidos de anabelfsagasti
#
# scrolleando 94 de 110
# Hasta el momento, se han encontrado 1141 seguidos de anabelfsagasti
#
# scrolleando 95 de 110
# Hasta el momento, se han encontrado 1153 seguidos de anabelfsagasti
#
# scrolleando 96 de 110
# Hasta el momento, se han encontrado 1165 seguidos de anabelfsagasti
#
# scrolleando 97 de 110
# Hasta el momento, se han encontrado 1177 seguidos de anabelfsagasti
#
# scrolleando 98 de 110
# Hasta el momento, se han encontrado 1189 seguidos de anabelfsagasti
#
# scrolleando 99 de 110
# Hasta el momento, se han encontrado 1201 seguidos de anabelfsagasti
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# scrolleando 100 de 110
# Hasta el momento, se han encontrado 1213 seguidos de anabelfsagasti
#
# scrolleando 101 de 110
# Hasta el momento, se han encontrado 1225 seguidos de anabelfsagasti
#
# scrolleando 102 de 110
# Hasta el momento, se han encontrado 1237 seguidos de anabelfsagasti
#
# scrolleando 103 de 110
# Hasta el momento, se han encontrado 1249 seguidos de anabelfsagasti
#
# scrolleando 104 de 110
# Hasta el momento, se han encontrado 1261 seguidos de anabelfsagasti
#
# scrolleando 105 de 110
# Hasta el momento, se han encontrado 1273 seguidos de anabelfsagasti
#
# scrolleando 106 de 110
# Hasta el momento, se han encontrado 1285 seguidos de anabelfsagasti
#
# scrolleando 107 de 110
# Hasta el momento, se han encontrado 1297 seguidos de anabelfsagasti
#
# scrolleando 108 de 110
# Hasta el momento, se han encontrado 1306 seguidos de anabelfsagasti
#
# scrolleando 109 de 110
# Hasta el momento, se han encontrado 1306 seguidos de anabelfsagasti
#
#
#
#
# Haciendo pausa de 5 minutos
#
#
#
# scrolleando 110 de 110
# Hasta el momento, se han encontrado 1306 seguidos de anabelfsagasti
#
#
# Driver cerrado...
#
# Guardando seguidos de anabelfsagasti...
#
#
#
#
#
#  anabelfsagasti tomo 133 minutos.
#
#
#
#
#
#
# Haciendo pausa inter usuario de 1.186047254417286 horas
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidos de mariofiad
#
#
# scrolleando 1 de 9
# Hasta el momento, se han encontrado 23 seguidos de mariofiad
#
# scrolleando 2 de 9
# Hasta el momento, se han encontrado 36 seguidos de mariofiad
#
# scrolleando 3 de 9
# Hasta el momento, se han encontrado 47 seguidos de mariofiad
#
# scrolleando 4 de 9
# Hasta el momento, se han encontrado 59 seguidos de mariofiad
#
# scrolleando 5 de 9
# Hasta el momento, se han encontrado 71 seguidos de mariofiad
#
# scrolleando 6 de 9
# Hasta el momento, se han encontrado 81 seguidos de mariofiad
#
# scrolleando 7 de 9
# Hasta el momento, se han encontrado 93 seguidos de mariofiad
#
# scrolleando 8 de 9
# Hasta el momento, se han encontrado 96 seguidos de mariofiad
#
# scrolleando 9 de 9
# Hasta el momento, se han encontrado 96 seguidos de mariofiad
#
#
# Driver cerrado...
#
# Guardando seguidos de mariofiad...
#
#
#
#
#
#  mariofiad tomo 7 minutos.
#
#
#
#
#
#
# Haciendo pausa inter usuario de 1.0937843525796804 horas
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidos de garcialarraburu
#
#
# scrolleando 1 de 20
# Hasta el momento, se han encontrado 24 seguidos de garcialarraburu
#
# scrolleando 2 de 20
# Hasta el momento, se han encontrado 37 seguidos de garcialarraburu
#
# scrolleando 3 de 20
# Hasta el momento, se han encontrado 49 seguidos de garcialarraburu
#
# scrolleando 4 de 20
# Hasta el momento, se han encontrado 61 seguidos de garcialarraburu
#
# scrolleando 5 de 20
# Hasta el momento, se han encontrado 73 seguidos de garcialarraburu
#
# scrolleando 6 de 20
# Hasta el momento, se han encontrado 85 seguidos de garcialarraburu
#
# scrolleando 7 de 20
# Hasta el momento, se han encontrado 97 seguidos de garcialarraburu
#
# scrolleando 8 de 20
# Hasta el momento, se han encontrado 109 seguidos de garcialarraburu
#
# scrolleando 9 de 20
# Hasta el momento, se han encontrado 121 seguidos de garcialarraburu
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# scrolleando 10 de 20
# Hasta el momento, se han encontrado 133 seguidos de garcialarraburu
#
# scrolleando 11 de 20
# Hasta el momento, se han encontrado 145 seguidos de garcialarraburu
#
# scrolleando 12 de 20
# Hasta el momento, se han encontrado 157 seguidos de garcialarraburu
#
# scrolleando 13 de 20
# Hasta el momento, se han encontrado 169 seguidos de garcialarraburu
#
# scrolleando 14 de 20
# Hasta el momento, se han encontrado 181 seguidos de garcialarraburu
#
# scrolleando 15 de 20
# Hasta el momento, se han encontrado 193 seguidos de garcialarraburu
#
# scrolleando 16 de 20
# Hasta el momento, se han encontrado 205 seguidos de garcialarraburu
#
# scrolleando 17 de 20
# Hasta el momento, se han encontrado 217 seguidos de garcialarraburu
#
# scrolleando 18 de 20
# Hasta el momento, se han encontrado 227 seguidos de garcialarraburu
#
# scrolleando 19 de 20
# Hasta el momento, se han encontrado 227 seguidos de garcialarraburu
#
#
#
#
# Haciendo pausa de 5 minutos
#
#
#
# scrolleando 20 de 20
# Hasta el momento, se han encontrado 227 seguidos de garcialarraburu
#
#
# Driver cerrado...
#
# Guardando seguidos de garcialarraburu...
#
#
#
#
#
#  garcialarraburu tomo 24 minutos.
#
#
#
#
#
#
# Haciendo pausa inter usuario de 1.0581514313612392 horas
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
#
# Scrapeando seguidos de silviagiacoppo
#
#
# scrolleando 1 de 5
# Hasta el momento, se han encontrado 23 seguidos de silviagiacoppo
#
# scrolleando 2 de 5
# Hasta el momento, se han encontrado 35 seguidos de silviagiacoppo
#
# scrolleando 3 de 5
# Hasta el momento, se han encontrado 47 seguidos de silviagiacoppo
#
# scrolleando 4 de 5
# Hasta el momento, se han encontrado 53 seguidos de silviagiacoppo
#
# scrolleando 5 de 5
# Hasta el momento, se han encontrado 53 seguidos de silviagiacoppo
#
#
# Driver cerrado...
#
# Guardando seguidos de silviagiacoppo...
#
#
#
#
#
#  silviagiacoppo tomo 5 minutos.
#
#
#
#
#
#
# Haciendo pausa inter usuario de 1.301607421967515 horas
