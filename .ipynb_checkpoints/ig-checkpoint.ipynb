# %% [markdown]
# # **Proyecto Instagram**
#
# # Cuenta uno:
# ### **Email:**
#
# redinstagramapp@gmail.com
#
# redinstagramapp2022
#
#
# ### **Instagram:**
#
# @proyectoredargentina
#
# redinstagram2020
#
#
# # Cuenta dos:
# ### **Email:**
#
# redinstagramapp2@gmail.com
#
# redinstagramapp2022
#
#
# ### **Instagram:**
#
# @proyectoredarg
#
# redinstagram2022
#
# ## **Facebook:**
# redinstagramapp@gmail.com
#
# redinstagramapp2022

# %%
# Usuarios a Scrapear
usuarios_interes = [
    
#'mauriciomacri', 'cristinafkirchner', 'horaciorodriguezlarreta', 
#  'joseluisespert', 'silbatakis', 'kicillofok', 'elisalilitacarrio','sergiomassaok', 
# 'coqui.capitanich', 'aliciakirchner', 'sergiounac', 'gustavovaldesok'
# 'juanluismanzur', 'gerardomoralesjujuy', 'gzamorasde', 'jschiaretti'         
'mariuvidal','patobullrich','gugalusto','alferdezok','javiermilei',  
]

# %%
# Credenciales
user = "proyectoredarg"
password = "redinstagram2022"

# %%
import os
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from time import sleep
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.headless = True
# !pip install webdriver-manager
from webdriver_manager.chrome import ChromeDriverManager
import random
import pandas as pd
# !pip install Workbook
# !pip install openpyxl
import openpyxl
from openpyxl import Workbook
# Out:
# Requirement already satisfied: selenium in c:\users\felipe\miniconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\felipe\miniconda3\lib\site-packages (from selenium) (1.26.2)
# Requirement already satisfied: webdriver-manager in c:\users\felipe\miniconda3\lib\site-packages (3.2.2)
# Requirement already satisfied: configparser in c:\users\felipe\miniconda3\lib\site-packages (from webdriver-manager) (5.0.1)
# Requirement already satisfied: crayons in c:\users\felipe\miniconda3\lib\site-packages (from webdriver-manager) (0.4.0)
# Requirement already satisfied: requests in c:\users\felipe\miniconda3\lib\site-packages (from webdriver-manager) (2.25.1)
# Requirement already satisfied: colorama in c:\users\felipe\miniconda3\lib\site-packages (from crayons->webdriver-manager) (0.4.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\felipe\miniconda3\lib\site-packages (from requests->webdriver-manager) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\felipe\miniconda3\lib\site-packages (from requests->webdriver-manager) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\felipe\miniconda3\lib\site-packages (from requests->webdriver-manager) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\felipe\miniconda3\lib\site-packages (from requests->webdriver-manager) (2020.12.5)
# Requirement already satisfied: Workbook in c:\users\felipe\miniconda3\lib\site-packages (1.1)
# Requirement already satisfied: xlwt in c:\users\felipe\miniconda3\lib\site-packages (from Workbook) (1.3.0)
# Requirement already satisfied: xlutils in c:\users\felipe\miniconda3\lib\site-packages (from Workbook) (2.0.0)
# Requirement already satisfied: xlrd>=0.7.2 in c:\users\felipe\miniconda3\lib\site-packages (from xlutils->Workbook) (2.0.1)
# Requirement already satisfied: openpyxl in c:\users\felipe\miniconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in c:\users\felipe\miniconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
def scrapear(usuario, user, password, navegacion_con_headers = False, cantidad_usuarios_a_scrapear = 10000000,
             scrapear_seguidores = False, scrapear_seguidos = False, download = True):
    
    start = time.time()
    
    # Funcion para evadir carteles
    def clickear(texto):
        path = f'//*[text() = "{texto}"]'
        boton = driver.find_element('xpath', path) 
        sleep(1)
        boton.click()
        sleep(2)
    
    def descargar(usuario, listado_seguidores, nombre):
        print(f'Guardando {nombre} de {usuario}...\n\n')
        nombre += '.xlsx'
        sumar = 0
        try:
            wb_obj = openpyxl.load_workbook(nombre)
            sumar += 1
        except:
            Workbook().save(nombre)
            wb_obj = openpyxl.load_workbook(nombre)

        # sheet
        worksheet = wb_obj.worksheets[0]

        # Columna de este usuario
        columna = worksheet.max_column + sumar

        # Nombre columna (usuario)
        worksheet.cell(row = 1, column = columna).value = usuario

        # Debajo, sus seguidos/seguidores
        for i,s in enumerate(listado_seguidores):
            worksheet.cell(row = i+2, column = columna).value = s

        wb_obj.save(nombre)
        wb_obj.close()
    
    # instanciamos webdriver (True or False)
    if navegacion_con_headers == True:
        driver = webdriver.Chrome(ChromeDriverManager().install())
    else:
        driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
    
    # ir a instagram.com
    driver.get('https://instagram.com/')
    sleep(10)
    
    # poner usuario
    username = driver.find_element('name','username')
    sleep(1)
    username.click()
    sleep(1)
    username.send_keys(user)
    sleep(1)
    
    # poner contraseña
    pw = driver.find_element('name','password')
    sleep(2)
    pw.click()
    sleep(2)
    pw.send_keys(password)
    sleep(2)
    
    # login
    try:
        login = driver.find_element('xpath','//div[text() = "Iniciar sesión"]')
    except:
        login = driver.find_element('xpath','//div[text() = "Log In"]')
    sleep(2)
    login.click()
    sleep(4)
    
    
    # Apretar "ahora no" a los pop ups, hasta que pueda buscarse un usuario
    contador_intentos = 0
    carteles_sorteados = False
    while carteles_sorteados == False and contador_intentos < 200:
        contador_intentos+=1
        try:
            buscador = driver.find_element('xpath',"//input[@placeholder='Buscar']")
            carteles_sorteados = True
        except:
            try:
                buscador = driver.find_element('xpath',"//input[@placeholder='Search']")
                carteles_sorteados = True
            except:
                try:
                    clickear('Not Now')      
                except:
                    try:
                        clickear('Ahora no')
                    except:
                        pass

    if contador_intentos == 200:
        print('\n\nEs posible que la cuenta haya sido blockeada.\n\n')
    
    url_usuario = 'https://www.instagram.com/'+usuario

    # SEGUIDORES
    if scrapear_seguidores == True:
        
        print(f'Scrapeando seguidores de {usuario}\n\n')

        # Entrar al usuario
        driver.get(url_usuario)
        sleep(8)

        # Acceder a seguidores
        seguidores_boton = driver.find_element('xpath',"//ul[@class='_aa_7']/li[2]//span")
        seguidores_boton.click()
        sleep(3)

        # cantidad de seguidores
        can_seguidores = driver.find_element('xpath',"//ul[@class='_aa_7']/li[2]//span").text
        if '.' in can_seguidores:
            cantidad_decimal = len(can_seguidores.split('.')[-1][:-1])
        else:
            cantidad_decimal = 0
        can_seguidores = int(can_seguidores.replace('K','0'*(3-cantidad_decimal)).replace('M','0'*(6-cantidad_decimal)).replace('.','').replace(',',''))

        # cuanto hay que scrollear
        scrollear_inicial = round(can_seguidores/12)+1

        # instanciamos seguidores_total
        seguidores_total = []
        cantidad_encontrados = []

        # scrollear y apendear
        for i in range(scrollear_inicial):
            i += 1

            #Cada x scrolls, pausa de x minutos
            if i % 10 == 0:
                minutos = random.uniform(3, 7)
                print(f'\n\n\nHaciendo pausa de {round(minutos)} minutos\n\n\n')
                time.sleep(minutos*60)
            
            # Cada x scrolls, scroll up to confuse bot detectors
            if i % 15 == 0:    
                driver.execute_script("""
                    var scrollt = document.querySelector('div[role="dialog"] ._aano')
                    scrollt.scrollTop = scrollt.scrollHeight - (scrollt.scrollHeight / 5)
                    """)

            # Print
            print(f'Scrolleando {i} de {scrollear_inicial}')

            # Scroll down
            driver.execute_script("""
                var scrollt = document.querySelector('div[role="dialog"] ._aano')
                scrollt.scrollTop = scrollt.scrollHeight
                """)

            time.sleep(random.uniform(20, 25))

            # Nuevos seguidores
            # Español
            seguidores = driver.find_elements('xpath',f"(//div[@class='_aae-']/li)[position()>={len(seguidores_total)}]//*/a")
            seguidores = [u.text for u in seguidores if len(u.text)>0]
            if len(seguidores) == 0:
                #Ingles
                seguidores = driver.find_elements('xpath',f"//div[position()>={len(seguidores_total)}]//*/span/a[@role = 'link']")
                seguidores = [elem.get_attribute('href').split('/')[-2] for elem in seguidores]

            # agregamos los nuevos seguidores
            seguidores_total.extend(seguidores)
            print(f'Hasta el momento, se han encontrado {len(seguidores_total)} seguidores de {usuario}\n')

            # Si no encontro nada en las ultimas 3 iters, break
            cantidad_encontrados.append(len(seguidores_total))
            try:
                ultimos = 20
                if len(set(cantidad_encontrados[-ultimos:])) == 1 and len(cantidad_encontrados) > ultimos:
                    print('\n\n\nINTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS\n')
                    break
            except:
                pass

            # break si se alcanzo maximo de usuarios
            if len(seguidores_total) > cantidad_usuarios_a_scrapear:
                break
                    
            time.sleep(random.uniform(20, 25))
    
        if download == True:
            descargar(usuario, seguidores_total, 'seguidores')

    # SEGUIDOS
    if scrapear_seguidos == True:
        
        print(f'Scrapeando seguidos de {usuario}\n\n')
        
        # Entrar al usuario
        start = time.time()
        driver.get(url_usuario)
        sleep(8)

        # Acceder a seguidos
        seguidos_boton = driver.find_element('xpath',"//ul[@class='_aa_7']/li[3]//span")
        seguidos_boton.click()
        sleep(3)

        # cantidad de seguidos
        can_seguidos = driver.find_element('xpath',"//ul[@class='_aa_7']/li[3]//span").text
        if '.' in can_seguidos:
            cantidad_decimal = len(can_seguidos.split('.')[-1][:-1])
        else:
            cantidad_decimal = 0
        can_seguidos = int(can_seguidos.replace('K','0'*(3-cantidad_decimal)).replace('M','0'*(6-cantidad_decimal)).replace('.','').replace(',',''))

        # cuanto hay que scrollear
        scrollear_inicial = round(can_seguidos/12)+1

        # instanciamos seguidos_total
        seguidos_total = []
        cantidad_encontrados = []

        # scrollear y apendear
        for i in range(scrollear_inicial):
            i += 1
            
            # Cada x scrolls, pausa random
            if i % 10 == 0:
                minutos = random.uniform(3, 7)
                print(f'\n\n\nHaciendo pausa de {round(minutos)} minutos\n\n\n')
                time.sleep(minutos*60)
                
            
            # Cada x scrolls, scroll up to confuse bot detectors
            if i % 15 == 0:    
                driver.execute_script("""
                    var scrollt = document.querySelector('div[role="dialog"] ._aano')
                    scrollt.scrollTop = scrollt.scrollHeight - (scrollt.scrollHeight / 5)
                    """)

            # Print
            print(f'scrolleando {i} de {scrollear_inicial}')

            # Scroll down
            driver.execute_script("""
                var scrollt = document.querySelector('div[role="dialog"] ._aano')
                scrollt.scrollTop = scrollt.scrollHeight
                """)
            time.sleep(random.uniform(20, 25))
            

            # Nuevos seguidos
            # Español
            seguidos = driver.find_elements('xpath',f"(//div[@class='_aae-']/li)[position()>={len(seguidos_total)}]//*/a")
            seguidos = [u.text for u in seguidos if len(u.text)>0]
            if len(seguidos) == 0:
                #Ingles
                seguidos = driver.find_elements('xpath',f"//div[position()>={len(seguidos_total)}]//*/span/a[@role = 'link']")
                seguidos = [elem.get_attribute('href').split('/')[-2] for elem in seguidos]

            # agregamos los nuevos seguidos
            seguidos_total.extend(seguidos)
            print(f'Hasta el momento, se han encontrado {len(seguidos_total)} seguidos de {usuario}\n')

            # Si no encontro nada en las ultimas 4 iters, break
            cantidad_encontrados.append(len(seguidos_total))
            try:
                ultimos = 20
                if len(set(cantidad_encontrados[-ultimos:])) == 1 and len(cantidad_encontrados) > ultimos:
                    print('\n\n\nINTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS\n')
                    break
            except:
                pass

            # break si se alcanzo maximo de usuarios
            if len(seguidos_total) > cantidad_usuarios_a_scrapear:
                break

            time.sleep(random.uniform(20, 25))
        
        if download == True:
            descargar(usuario, seguidos_total, 'seguidos')
    
    #Tiempo de ejecucion
    end = time.time()
    print(f'\n\n\nEl usuario tomó {round((end-start)/60)} minutos\n\n\n')
    
    # Cerrar webdriver
    driver.close()
    print('Driver cerrado...')
        
    # Return
    if scrapear_seguidores == True and scrapear_seguidos == True:
        return seguidores_total, seguidos_total
    elif scrapear_seguidores == True and scrapear_seguidos == False:
        return seguidores_total
    elif scrapear_seguidores == False and scrapear_seguidos == True:
        return seguidos_total 
    else:
        return print('Por favor, instanciar la funcion con scrapear_seguidores o scrapear_seguidos en True')

# %%
seguidores_todos = {}
seguidos_todos = {}

start = time.time()

for usuario in usuarios_interes:
    try:
        
        # Obtener seguidores/seguidos
        seguidores_total, seguidos_total = scrapear(usuario, 
                                                    cantidad_usuarios_a_scrapear = 5000,
                                                    scrapear_seguidos = True,
                                                    user = user, password = password)

        # Guardarlo en dict
        seguidores_todos[usuario] = seguidores_total
        seguidos_todos[usuario] = seguidos_total
        
    
        # pausa random
        horas = random.uniform(2, 4)
        print(f'\n\n\nHaciendo pausa inter usuario de {round(minutos)} minutos\n\n\n')
        time.sleep(horas*60*60)
        
    except:
        pass

end = time.time()

print(f'\n\n\nTodos los usuarios tomaron {round((end-start)/60)} minutos\n\n\n')
# Out:
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidores de cristinafkirchner
#
#
# Scrolleando 1 de 108334
# Hasta el momento, se han encontrado 24 seguidores de cristinafkirchner
#
# Scrolleando 2 de 108334
# Hasta el momento, se han encontrado 25 seguidores de cristinafkirchner
#
# Scrolleando 3 de 108334
# Hasta el momento, se han encontrado 37 seguidores de cristinafkirchner
#
# Scrolleando 4 de 108334
# Hasta el momento, se han encontrado 49 seguidores de cristinafkirchner
#
# Scrolleando 5 de 108334
# Hasta el momento, se han encontrado 61 seguidores de cristinafkirchner
#
# Scrolleando 6 de 108334
# Hasta el momento, se han encontrado 73 seguidores de cristinafkirchner
#
# Scrolleando 7 de 108334
# Hasta el momento, se han encontrado 85 seguidores de cristinafkirchner
#
# Scrolleando 8 de 108334
# Hasta el momento, se han encontrado 97 seguidores de cristinafkirchner
#
# Scrolleando 9 de 108334
# Hasta el momento, se han encontrado 109 seguidores de cristinafkirchner
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# Scrolleando 10 de 108334
# Hasta el momento, se han encontrado 121 seguidores de cristinafkirchner
#
# Scrolleando 11 de 108334
# Hasta el momento, se han encontrado 133 seguidores de cristinafkirchner
#
# Scrolleando 12 de 108334
# Hasta el momento, se han encontrado 145 seguidores de cristinafkirchner
#
# Scrolleando 13 de 108334
# Hasta el momento, se han encontrado 157 seguidores de cristinafkirchner
#
# Scrolleando 14 de 108334
# Hasta el momento, se han encontrado 169 seguidores de cristinafkirchner
#
# Scrolleando 15 de 108334
# Hasta el momento, se han encontrado 180 seguidores de cristinafkirchner
#
# Scrolleando 16 de 108334
# Hasta el momento, se han encontrado 192 seguidores de cristinafkirchner
#
# Scrolleando 17 de 108334
# Hasta el momento, se han encontrado 204 seguidores de cristinafkirchner
#
# Scrolleando 18 de 108334
# Hasta el momento, se han encontrado 216 seguidores de cristinafkirchner
#
# Scrolleando 19 de 108334
# Hasta el momento, se han encontrado 228 seguidores de cristinafkirchner
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# Scrolleando
seguidores de cristinafkirchner
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 280 de 108334
# Hasta el momento, se han encontrado 3251 seguidores de cristinafkirchner
#
# Scrolleando 281 de 108334
# Hasta el momento, se han encontrado 3263 seguidores de cristinafkirchner
#
# Scrolleando 282 de 108334
# Hasta el momento, se han encontrado 3274 seguidores de cristinafkirchner
#
# Scrolleando 283 de 108334
# Hasta el momento, se han encontrado 3286 seguidores de cristinafkirchner
#
# Scrolleando 284 de 108334
# Hasta el momento, se han encontrado 3298 seguidores de cristinafkirchner
#
# Scrolleando 285 de 108334
# Hasta el momento, se han encontrado 3309 seguidores de cristinafkirchner
#
# Scrolleando 286 de 108334
# Hasta el momento, se han encontrado 3320 seguidores de cristinafkirchner
#
# Scrolleando 287 de 108334
# Hasta el momento, se han encontrado 3332 seguidores de cristinafkirchner
#
# Scrolleando 288 de 108334
# Hasta el momento, se han encontrado 3344 seguidores de cristinafkirchner
#
# Scrolleando 289 de 108334
# Hasta el momento, se han encontrado 3355 seguidores de cristinafkirchner
#
#
#
#
# Haciendo pausa de 1 minutos
#
#
#
# Scrolleando 290 de 108334
# Hasta el momento, se han encontrado 3367 seguidores de cristinafkirchner
#
# Scrolleando 291 de 108334
# Hasta el momento, se han encontrado 3379 seguidores de cristinafkirchner
#
# Scrolleando 292 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 293 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 294 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 295 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 296 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 297 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 298 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 299 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# Scrolleando 300 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 301 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 302 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 303 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 304 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 305 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 306 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 307 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 308 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 309 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
#
#
#
# Haciendo pausa de 1 minutos
#
#
#
# Scrolleando 310 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
# Scrolleando 311 de 108334
# Hasta el momento, se han encontrado 3391 seguidores de cristinafkirchner
#
#
#
#
# INTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS
#
# Guardando seguidores de cristinafkirchner...
#
#
# Scrapeando seguidos de cristinafkirchner
#
#
# scrolleando 1 de 6
# Hasta el momento, se han encontrado 24 seguidos de cristinafkirchner
#
# scrolleando 2 de 6
# Hasta el momento, se han encontrado 37 seguidos de cristinafkirchner
#
# scrolleando 3 de 6
# Hasta el momento, se han encontrado 49 seguidos de cristinafkirchner
#
# scrolleando 4 de 6
# Hasta el momento, se han encontrado 61 seguidos de cristinafkirchner
#
# scrolleando 5 de 6
# Hasta el momento, se han encontrado 64 seguidos de cristinafkirchner
#
# scrolleando 6 de 6
# Hasta el momento, se han encontrado 64 seguidos de cristinafkirchner
#
# Guardando seguidos de cristinafkirchner...
#
#
#
#
#
# El usuario tomó 2 minutos
#
#
#
#
#
#
# Haciendo pausa inter usuario de 50 minutos
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidores de horaciorodriguezlarreta
#
#
# Scrolleando 1 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 2 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 3 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 4 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 5 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 6 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 7 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 8 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 9 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
#
#
#
# Haciendo pausa de 1 minutos
#
#
#
# Scrolleando 10 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 11 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 12 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 13 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 14 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 15 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 16 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 17 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 18 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 19 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# Scrolleando 20 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
# Scrolleando 21 de 43834
# Hasta el momento, se han encontrado 0 seguidores de horaciorodriguezlarreta
#
#
#
#
# INTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS
#
# Guardando seguidores de horaciorodriguezlarreta...
#
#
# Scrapeando seguidos de horaciorodriguezlarreta
#
#
# scrolleando 1 de 25
# Hasta el momento, se han encontrado 24 seguidos de horaciorodriguezlarreta
#
# scrolleando 2 de 25
# Hasta el momento, se han encontrado 37 seguidos de horaciorodriguezlarreta
#
# scrolleando 3 de 25
# Hasta el momento, se han encontrado 49 seguidos de horaciorodriguezlarreta
#
# scrolleando 4 de 25
# Hasta el momento, se han encontrado 61 seguidos de horaciorodriguezlarreta
#
# scrolleando 5 de 25
# Hasta el momento, se han encontrado 73 seguidos de horaciorodriguezlarreta
#
# scrolleando 6 de 25
# Hasta el momento, se han encontrado 85 seguidos de horaciorodriguezlarreta
#
# scrolleando 7 de 25
# Hasta el momento, se han encontrado 97 seguidos de horaciorodriguezlarreta
#
# scrolleando 8 de 25
# Hasta el momento, se han encontrado 109 seguidos de horaciorodriguezlarreta
#
# scrolleando 9 de 25
# Hasta el momento, se han encontrado 121 seguidos de horaciorodriguezlarreta
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# scrolleando 10 de 25
# Hasta el momento, se han encontrado 133 seguidos de horaciorodriguezlarreta
#
# scrolleando 11 de 25
# Hasta el momento, se han encontrado 145 seguidos de horaciorodriguezlarreta
#
# scrolleando 12 de 25
# Hasta el momento, se han encontrado 157 seguidos de horaciorodriguezlarreta
#
# scrolleando 13 de 25
# Hasta el momento, se han encontrado 169 seguidos de horaciorodriguezlarreta
#
# scrolleando 14 de 25
# Hasta el momento, se han encontrado 181 seguidos de horaciorodriguezlarreta
#
# scrolleando 15 de 25
# Hasta el momento, se han encontrado 193 seguidos de horaciorodriguezlarreta
#
# scrolleando 16 de 25
# Hasta el momento, se han encontrado 205 seguidos de horaciorodriguezlarreta
#
# scrolleando 17 de 25
# Hasta el momento, se han encontrado 217 seguidos de horaciorodriguezlarreta
#
# scrolleando 18 de 25
# Hasta el momento, se han encontrado 229 seguidos de horaciorodriguezlarreta
#
# scrolleando 19 de 25
# Hasta el momento, se han encontrado 241 seguidos de horaciorodriguezlarreta
#
#
#
#
# Haciendo pausa de 1 minutos
#
#
#
# scrolleando 20 de 25
# Hasta el momento, se han encontrado 253 seguidos de horaciorodriguezlarreta
#
# scrolleando 21 de 25
# Hasta el momento, se han encontrado 265 seguidos de horaciorodriguezlarreta
#
# scrolleando 22 de 25
# Hasta el momento, se han encontrado 277 seguidos de horaciorodriguezlarreta
#
# scrolleando 23 de 25
# Hasta el momento, se han encontrado 289 seguidos de horaciorodriguezlarreta
#
# scrolleando 24 de 25
# Hasta el momento, se han encontrado 291 seguidos de horaciorodriguezlarreta
#
# scrolleando 25 de 25
# Hasta el momento, se han encontrado 291 seguidos de horaciorodriguezlarreta
#
# Guardando seguidos de horaciorodriguezlarreta...
#
#
#
#
#
# El usuario tomó 12 minutos
#
#
#
#
#
#
# Haciendo pausa inter usuario de 46 minutos
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidores de alferdezok
#
#
# Scrolleando 1 de 208334
# Hasta el momento, se han encontrado 24 seguidores de alferdezok
#
# Scrolleando 2 de 208334
# Hasta el momento, se han encontrado 37 seguidores de alferdezok
#
# Scrolleando 3 de 208334
# Hasta el momento, se han encontrado 49 seguidores de alferdezok
#
# Scrolleando 4 de 208334
# Hasta el momento, se han encontrado 61 seguidores de alferdezok
#
# Scrolleando 5 de 208334
# Hasta el momento, se han encontrado 73 seguidores de alferdezok
#
# Scrolleando 6 de 208334
# Hasta el momento, se han encontrado 84 seguidores de alferdezok
#
# Scrolleando 7 de 208334
# Hasta el momento, se han encontrado 96 seguidores de alferdezok
#
# Scrolleando 8 de 208334
# Hasta el momento, se han encontrado 108 seguidores de alferdezok
#
# Scrolleando 9 de 208334
# Hasta el momento, se han encontrado 120 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 10 de 208334
# Hasta el momento, se han encontrado 132 seguidores de alferdezok
#
# Scrolleando 11 de 208334
# Hasta el momento, se han encontrado 144 seguidores de alferdezok
#
# Scrolleando 12 de 208334
# Hasta el momento, se han encontrado 156 seguidores de alferdezok
#
# Scrolleando 13 de 208334
# Hasta el momento, se han encontrado 168 seguidores de alferdezok
#
# Scrolleando 14 de 208334
# Hasta el momento, se han encontrado 180 seguidores de alferdezok
#
# Scrolleando 15 de 208334
# Hasta el momento, se han encontrado 192 seguidores de alferdezok
#
# Scrolleando 16 de 208334
# Hasta el momento, se han encontrado 204 seguidores de alferdezok
#
# Scrolleando 17 de 208334
# Hasta el momento, se han encontrado 215 seguidores de alferdezok
#
# Scrolleando 18 de 208334
# Hasta el momento, se han encontrado 227 seguidores de alferdezok
#
# Scrolleando 19 de 208334
# Hasta el momento, se han encontrado 239 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 1 minutos
#
#
#
# Scrolleando 20 de 208334
# Hasta el momento, se han encontrado 251 seguidores de alferdezok
#
# Scrolleando 21 de 208334
# Hasta el momento, se han encontrado 263 seguidores de alferdezok
#
# Scrolleando 22 de 208334
# Hasta el momento, se han encontrado 275 seguidores de alferdezok
#
# Scrolleando 23 de 208334
# Hasta el momento, se han encontrado 287 seguidores de alferdezok
#
# Scrolleando 24 de 208334
# Hasta el momento, se han encontrado 299 seguidores de alferdezok
#
# Scrolleando 25 de 208334
# Hasta el momento, se han encontrado 311 seguidores de alferdezok
#
# Scrolleando 26 de 208334
# Hasta el momento, se han encontrado 323 seguidores de alferdezok
#
# Scrolleando 27 de 208334
# Hasta el momento, se han encontrado 334 seguidores de alferdezok
#
# Scrolleando 28 de 208334
# Hasta el momento, se han encontrado 346 seguidores de alferdezok
#
# Scrolleando 29 de 208334
# Hasta el momento, se han encontrado 358 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# Scrolleando 30 de 208334
# Hasta el momento, se han encontrado 370 seguidores de alferdezok
#
# Scrolleando 31 de 208334
# Hasta el momento, se han encontrado 382 seguidores de alferdezok
#
# Scrolleando 32 de 208334
# Hasta el momento, se han encontrado 394 seguidores de alferdezok
#
# Scrolleando 33 de 208334
# Hasta el momento, se han encontrado 406 seguidores de alferdezok
#
# Scrolleando 34 de 208334
# Hasta el momento, se han encontrado 417 seguidores de alferdezok
#
# Scrolleando 35 de 208334
# Hasta el momento, se han encontrado 428 seguidores de alferdezok
#
# Scrolleando 36 de 208334
# Hasta el momento, se han encontrado 440 seguidores de alferdezok
#
# Scrolleando 37 de 208334
# Hasta el momento, se han encontrado 452 seguidores de alferdezok
#
# Scrolleando 38 de 208334
# Hasta el momento, se han encontrado 464 seguidores de alferdezok
#
# Scrolleando 39 de 208334
# Hasta el momento, se han encontrado 476 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 40 de 208334
# Hasta el momento, se han encontrado 488 seguidores de alferdezok
#
# Scrolleando 41 de 208334
# Hasta el momento, se han encontrado 500 seguidores de alferdezok
#
# Scrolleando 42 de 208334
# Hasta el momento, se han encontrado 512 seguidores de alferdezok
#
# Scrolleando 43 de 208334
# Hasta el momento, se han encontrado 524 seguidores de alferdezok
#
# Scrolleando 44 de 208334
# Hasta el momento, se han encontrado 536 seguidores de alferdezok
#
# Scrolleando 45 de 208334
# Hasta el momento, se han encontrado 548 seguidores de alferdezok
#
# Scrolleando 46 de 208334
# Hasta el momento, se han encontrado 560 seguidores de alferdezok
#
# Scrolleando 47 de 208334
# Hasta el momento, se han encontrado 572 seguidores de alferdezok
#
# Scrolleando 48 de 208334
# Hasta el momento, se han encontrado 584 seguidores de alferdezok
#
# Scrolleando 49 de 208334
# Hasta el momento, se han encontrado 596 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 50 de 208334
# Hasta el momento, se han encontrado 608 seguidores de alferdezok
#
# Scrolleando 51 de 208334
# Hasta el momento, se han encontrado 620 seguidores de alferdezok
#
# Scrolleando 52 de 208334
# Hasta el momento, se han encontrado 631 seguidores de alferdezok
#
# Scrolleando 53 de 208334
# Hasta el momento, se han encontrado 643 seguidores de alferdezok
#
# Scrolleando 54 de 208334
# Hasta el momento, se han encontrado 655 seguidores de alferdezok
#
# Scrolleando 55 de 208334
# Hasta el momento, se han encontrado 667 seguidores de alferdezok
#
# Scrolleando 56 de 208334
# Hasta el momento, se han encontrado 679 seguidores de alferdezok
#
# Scrolleando 57 de 208334
# Hasta el momento, se han encontrado 690 seguidores de alferdezok
#
# Scrolleando 58 de 208334
# Hasta el momento, se han encontrado 701 seguidores de alferdezok
#
# Scrolleando 59 de 208334
# Hasta el momento, se han encontrado 713 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# Scrolleando 60 de 208334
# Hasta el momento, se han encontrado 725 seguidores de alferdezok
#
# Scrolleando 61 de 208334
# Hasta el momento, se han encontrado 737 seguidores de alferdezok
#
# Scrolleando 62 de 208334
# Hasta el momento, se han encontrado 749 seguidores de alferdezok
#
# Scrolleando 63 de 208334
# Hasta el momento, se han encontrado 761 seguidores de alferdezok
#
# Scrolleando 64 de 208334
# Hasta el momento, se han encontrado 773 seguidores de alferdezok
#
# Scrolleando 65 de 208334
# Hasta el momento, se han encontrado 785 seguidores de alferdezok
#
# Scrolleando 66 de 208334
# Hasta el momento, se han encontrado 796 seguidores de alferdezok
#
# Scrolleando 67 de 208334
# Hasta el momento, se han encontrado 808 seguidores de alferdezok
#
# Scrolleando 68 de 208334
# Hasta el momento, se han encontrado 820 seguidores de alferdezok
#
# Scrolleando 69 de 208334
# Hasta el momento, se han encontrado 831 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 70 de 208334
# Hasta el momento, se han encontrado 842 seguidores de alferdezok
#
# Scrolleando 71 de 208334
# Hasta el momento, se han encontrado 854 seguidores de alferdezok
#
# Scrolleando 72 de 208334
# Hasta el momento, se han encontrado 866 seguidores de alferdezok
#
# Scrolleando 73 de 208334
# Hasta el momento, se han encontrado 877 seguidores de alferdezok
#
# Scrolleando 74 de 208334
# Hasta el momento, se han encontrado 889 seguidores de alferdezok
#
# Scrolleando 75 de 208334
# Hasta el momento, se han encontrado 901 seguidores de alferdezok
#
# Scrolleando 76 de 208334
# Hasta el momento, se han encontrado 912 seguidores de alferdezok
#
# Scrolleando 77 de 208334
# Hasta el momento, se han encontrado 924 seguidores de alferdezok
#
# Scrolleando 78 de 208334
# Hasta el momento, se han encontrado 936 seguidores de alferdezok
#
# Scrolleando 79 de 208334
# Hasta el momento, se han encontrado 948 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 80 de 208334
# Hasta el momento, se han encontrado 960 seguidores de alferdezok
#
# Scrolleando 81 de 208334
# Hasta el momento, se han encontrado 972 seguidores de alferdezok
#
# Scrolleando 82 de 208334
# Hasta el momento, se han encontrado 983 seguidores de alferdezok
#
# Scrolleando 83 de 208334
# Hasta el momento, se han encontrado 995 seguidores de alferdezok
#
# Scrolleando 84 de 208334
# Hasta el momento, se han encontrado 1006 seguidores de alferdezok
#
# Scrolleando 85 de 208334
# Hasta el momento, se han encontrado 1018 seguidores de alferdezok
#
# Scrolleando 86 de 208334
# Hasta el momento, se han encontrado 1030 seguidores de alferdezok
#
# Scrolleando 87 de 208334
# Hasta el momento, se han encontrado 1041 seguidores de alferdezok
#
# Scrolleando 88 de 208334
# Hasta el momento, se han encontrado 1053 seguidores de alferdezok
#
# Scrolleando 89 de 208334
# Hasta el momento, se han encontrado 1065 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# Scrolleando 90 de 208334
# Hasta el momento, se han encontrado 1077 seguidores de alferdezok
#
# Scrolleando 91 de 208334
# Hasta el momento, se han encontrado 1089 seguidores de alferdezok
#
# Scrolleando 92 de 208334
# Hasta el momento, se han encontrado 1101 seguidores de alferdezok
#
# Scrolleando 93 de 208334
# Hasta el momento, se han encontrado 1113 seguidores de alferdezok
#
# Scrolleando 94 de 208334
# Hasta el momento, se han encontrado 1125 seguidores de alferdezok
#
# Scrolleando 95 de 208334
# Hasta el momento, se han encontrado 1137 seguidores de alferdezok
#
# Scrolleando 96 de 208334
# Hasta el momento, se han encontrado 1149 seguidores de alferdezok
#
# Scrolleando 97 de 208334
# Hasta el momento, se han encontrado 1160 seguidores de alferdezok
#
# Scrolleando 98 de 208334
# Hasta el momento, se han encontrado 1172 seguidores de alferdezok
#
# Scrolleando 99 de 208334
# Hasta el momento, se han encontrado 1184 seguidores de alferdezok
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# Scrolleando 100 de 208334
# Hasta el momento, se han encontrado 1196 seguidores de alferdezok
#
# Scrolleando 101 de 208334
# ...
#
# Scrolleando 16 de 5451
# Hasta el momento, se han encontrado 0 seguidores de aliciakirchner
#
# Scrolleando 17 de 5451
# Hasta el momento, se han encontrado 0 seguidores de aliciakirchner
#
# Scrolleando 18 de 5451
# Hasta el momento, se han encontrado 0 seguidores de aliciakirchner
#
# Scrolleando 19 de 5451
# Hasta el momento, se han encontrado 0 seguidores de aliciakirchner
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 20 de 5451
# Hasta el momento, se han encontrado 0 seguidores de aliciakirchner
#
# Scrolleando 21 de 5451
# Hasta el momento, se han encontrado 0 seguidores de aliciakirchner
#
#
#
#
# INTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS
#
# Guardando seguidores de aliciakirchner...
#
#
# Scrapeando seguidos de aliciakirchner
#
#
# scrolleando 1 de 12
# Hasta el momento, se han encontrado 24 seguidos de aliciakirchner
#
# scrolleando 2 de 12
# Hasta el momento, se han encontrado 37 seguidos de aliciakirchner
#
# scrolleando 3 de 12
# Hasta el momento, se han encontrado 49 seguidos de aliciakirchner
#
# scrolleando 4 de 12
# Hasta el momento, se han encontrado 61 seguidos de aliciakirchner
#
# scrolleando 5 de 12
# Hasta el momento, se han encontrado 73 seguidos de aliciakirchner
#
# scrolleando 6 de 12
# Hasta el momento, se han encontrado 85 seguidos de aliciakirchner
#
# scrolleando 7 de 12
# Hasta el momento, se han encontrado 97 seguidos de aliciakirchner
#
# scrolleando 8 de 12
# Hasta el momento, se han encontrado 109 seguidos de aliciakirchner
#
# scrolleando 9 de 12
# Hasta el momento, se han encontrado 121 seguidos de aliciakirchner
#
#
#
#
# Haciendo pausa de 1 minutos
#
#
#
# scrolleando 10 de 12
# Hasta el momento, se han encontrado 133 seguidos de aliciakirchner
#
# scrolleando 11 de 12
# Hasta el momento, se han encontrado 137 seguidos de aliciakirchner
#
# scrolleando 12 de 12
# Hasta el momento, se han encontrado 137 seguidos de aliciakirchner
#
# Guardando seguidos de aliciakirchner...
#
#
#
#
#
# El usuario tomó 6 minutos
#
#
#
#
#
#
# Haciendo pausa inter usuario de 51 minutos
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidores de sergiounac
#
#
# Scrolleando 1 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 2 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 3 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 4 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 5 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 6 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 7 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 8 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 9 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# Scrolleando 10 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 11 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 12 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 13 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 14 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 15 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 16 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 17 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 18 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 19 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 20 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
# Scrolleando 21 de 5243
# Hasta el momento, se han encontrado 0 seguidores de sergiounac
#
#
#
#
# INTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS
#
# Guardando seguidores de sergiounac...
#
#
# Scrapeando seguidos de sergiounac
#
#
# scrolleando 1 de 16
# Hasta el momento, se han encontrado 24 seguidos de sergiounac
#
# scrolleando 2 de 16
# Hasta el momento, se han encontrado 37 seguidos de sergiounac
#
# scrolleando 3 de 16
# Hasta el momento, se han encontrado 49 seguidos de sergiounac
#
# scrolleando 4 de 16
# Hasta el momento, se han encontrado 61 seguidos de sergiounac
#
# scrolleando 5 de 16
# Hasta el momento, se han encontrado 73 seguidos de sergiounac
#
# scrolleando 6 de 16
# Hasta el momento, se han encontrado 85 seguidos de sergiounac
#
# scrolleando 7 de 16
# Hasta el momento, se han encontrado 97 seguidos de sergiounac
#
# scrolleando 8 de 16
# Hasta el momento, se han encontrado 109 seguidos de sergiounac
#
# scrolleando 9 de 16
# Hasta el momento, se han encontrado 121 seguidos de sergiounac
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# scrolleando 10 de 16
# Hasta el momento, se han encontrado 133 seguidos de sergiounac
#
# scrolleando 11 de 16
# Hasta el momento, se han encontrado 145 seguidos de sergiounac
#
# scrolleando 12 de 16
# Hasta el momento, se han encontrado 157 seguidos de sergiounac
#
# scrolleando 13 de 16
# Hasta el momento, se han encontrado 169 seguidos de sergiounac
#
# scrolleando 14 de 16
# Hasta el momento, se han encontrado 181 seguidos de sergiounac
#
# scrolleando 15 de 16
# Hasta el momento, se han encontrado 186 seguidos de sergiounac
#
# scrolleando 16 de 16
# Hasta el momento, se han encontrado 186 seguidos de sergiounac
#
# Guardando seguidos de sergiounac...
#
#
#
#
#
# El usuario tomó 9 minutos
#
#
#
#
#
#
# Haciendo pausa inter usuario de 51 minutos
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidores de gustavovaldesokjuanluismanzur
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidores de gerardomoralesjujuy
#
#
# Scrolleando 1 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 2 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 3 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 4 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 5 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 6 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 7 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 8 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 9 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# Scrolleando 10 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 11 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 12 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 13 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 14 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 15 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 16 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 17 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 18 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 19 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
#
#
#
# Haciendo pausa de 4 minutos
#
#
#
# Scrolleando 20 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
# Scrolleando 21 de 3726
# Hasta el momento, se han encontrado 0 seguidores de gerardomoralesjujuy
#
#
#
#
# INTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS
#
# Guardando seguidores de gerardomoralesjujuy...
#
#
# Scrapeando seguidos de gerardomoralesjujuy
#
#
# scrolleando 1 de 3
# Hasta el momento, se han encontrado 22 seguidos de gerardomoralesjujuy
#
# scrolleando 2 de 3
# Hasta el momento, se han encontrado 23 seguidos de gerardomoralesjujuy
#
# scrolleando 3 de 3
# Hasta el momento, se han encontrado 23 seguidos de gerardomoralesjujuy
#
# Guardando seguidos de gerardomoralesjujuy...
#
#
#
#
#
# El usuario tomó 1 minutos
#
#
#
#
#
#
# Haciendo pausa inter usuario de 44 minutos
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidores de gzamorasde
#
#
# Scrolleando 1 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 2 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 3 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 4 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 5 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 6 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 7 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 8 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 9 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 10 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 11 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 12 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 13 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 14 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 15 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 16 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 17 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 18 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 19 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# Scrolleando 20 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
# Scrolleando 21 de 3734
# Hasta el momento, se han encontrado 0 seguidores de gzamorasde
#
#
#
#
# INTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS
#
# Guardando seguidores de gzamorasde...
#
#
# Scrapeando seguidos de gzamorasde
#
#
# scrolleando 1 de 8
# Hasta el momento, se han encontrado 24 seguidos de gzamorasde
#
# scrolleando 2 de 8
# Hasta el momento, se han encontrado 37 seguidos de gzamorasde
#
# scrolleando 3 de 8
# Hasta el momento, se han encontrado 49 seguidos de gzamorasde
#
# scrolleando 4 de 8
# Hasta el momento, se han encontrado 61 seguidos de gzamorasde
#
# scrolleando 5 de 8
# Hasta el momento, se han encontrado 73 seguidos de gzamorasde
#
# scrolleando 6 de 8
# Hasta el momento, se han encontrado 85 seguidos de gzamorasde
#
# scrolleando 7 de 8
# Hasta el momento, se han encontrado 89 seguidos de gzamorasde
#
# scrolleando 8 de 8
# Hasta el momento, se han encontrado 89 seguidos de gzamorasde
#
# Guardando seguidos de gzamorasde...
#
#
#
#
#
# El usuario tomó 3 minutos
#
#
#
#
#
#
# Haciendo pausa inter usuario de 41 minutos
# [WDM] - Current google-chrome version is 105.0.5195
# [WDM] - Get LATEST driver version for 105.0.5195
# [WDM] - Driver [C:\Users\Felipe\.wdm\drivers\chromedriver\win32\105.0.5195.52\chromedriver.exe] found in cache
# Scrapeando seguidores de jschiaretti
#
#
# Scrolleando 1 de 5168
# Hasta el momento, se han encontrado 50 seguidores de jschiaretti
#
# Scrolleando 2 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 3 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 4 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 5 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 6 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 7 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 8 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 9 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# Scrolleando 10 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 11 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 12 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 13 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 14 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 15 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 16 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 17 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 18 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 19 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
#
#
#
# Haciendo pausa de 3 minutos
#
#
#
# Scrolleando 20 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
# Scrolleando 21 de 5168
# Hasta el momento, se han encontrado 51 seguidores de jschiaretti
#
#
#
#
# INTERRUPCION: NO SE ENCUENTRAN NUEVAS CUENTAS
#
# Guardando seguidores de jschiaretti...
#
#
# Scrapeando seguidos de jschiaretti
#
#
# scrolleando 1 de 19
# Hasta el momento, se han encontrado 24 seguidos de jschiaretti
#
# scrolleando 2 de 19
# Hasta el momento, se han encontrado 37 seguidos de jschiaretti
#
# scrolleando 3 de 19
# Hasta el momento, se han encontrado 49 seguidos de jschiaretti
#
# scrolleando 4 de 19
# Hasta el momento, se han encontrado 61 seguidos de jschiaretti
#
# scrolleando 5 de 19
# Hasta el momento, se han encontrado 73 seguidos de jschiaretti
#
# scrolleando 6 de 19
# Hasta el momento, se han encontrado 85 seguidos de jschiaretti
#
# scrolleando 7 de 19
# Hasta el momento, se han encontrado 97 seguidos de jschiaretti
#
# scrolleando 8 de 19
# Hasta el momento, se han encontrado 109 seguidos de jschiaretti
#
# scrolleando 9 de 19
# Hasta el momento, se han encontrado 121 seguidos de jschiaretti
#
#
#
#
# Haciendo pausa de 2 minutos
#
#
#
# scrolleando 10 de 19
# Hasta el momento, se han encontrado 133 seguidos de jschiaretti
#
# scrolleando 11 de 19
# Hasta el momento, se han encontrado 145 seguidos de jschiaretti
#
# scrolleando 12 de 19
# Hasta el momento, se han encontrado 157 seguidos de jschiaretti
#
# scrolleando 13 de 19
# Hasta el momento, se han encontrado 169 seguidos de jschiaretti
#
# scrolleando 14 de 19
# Hasta el momento, se han encontrado 181 seguidos de jschiaretti
#
# scrolleando 15 de 19
# Hasta el momento, se han encontrado 193 seguidos de jschiaretti
#
# scrolleando 16 de 19
# Hasta el momento, se han encontrado 205 seguidos de jschiaretti
#
# scrolleando 17 de 19
# Hasta el momento, se han encontrado 217 seguidos de jschiaretti
#
# scrolleando 18 de 19
# Hasta el momento, se han encontrado 218 seguidos de jschiaretti
#
# scrolleando 19 de 19
# Hasta el momento, se han encontrado 218 seguidos de jschiaretti
#
# Guardando seguidos de jschiaretti...
#
#
#
#
#
# El usuario tomó 9 minutos
#
#
#
#
#
#
# Haciendo pausa inter usuario de 47 minutos
#
#
#
#
#
#
# Todos los usuarios tomaron 1539 minutos
